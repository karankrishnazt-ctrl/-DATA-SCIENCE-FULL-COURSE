# %%
# dictionary is a data structure that stre data in key value pair
# unordered, keys are unique and immutable

# %%
d = {}
type(d)
# Out:
# dict

# %%
d ={"name":"karan","email": "kk@gmail.com","contact": 1234}

# %%
type(d)
# Out:
# dict

# %%
d
# Out:
# {'name': 'karan', 'email': 'kk@gmail.com', 'contact': 1234}

# %%
d.keys()
# Out:
# dict_keys(['name', 'email', 'contact'])

# %%
d.values()
# Out:
# dict_values(['karan', 'kk@gmail.com', 1234])

# %%
d.items()
# Out:
# dict_items([('name', 'karan'), ('email', 'kk@gmail.com'), ('contact', 1234)])

# %%
d1 = d.copy()

# %%
d1
# Out:
# {'name': 'karan', 'email': 'kk@gmail.com', 'contact': 1234}

# %%
del d1

# %%
d1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 d1
#
# NameError: name 'd1' is not defined

# %%
d.pop('contact')
# Out:
# 1234

# %%
d
# Out:
# {'name': 'karan', 'email': 'kk@gmail.com'}

# %%
d1 = {"course": "DS","start": "20th june"}

# %%
d.update(d1)

# %%
d
# Out:
# {'name': 'karan',
#  'email': 'kk@gmail.com',
#  'course': 'DS',
#  'start': '20th june'}

# %%
d['start']
# Out:
# '20th june'

# %%
d.get('start')
# Out:
# '20th june'

# %%
d.fromkeys((1,2,3),('a','b','c'))
# Out:
# {1: ('a', 'b', 'c'), 2: ('a', 'b', 'c'), 3: ('a', 'b', 'c')}

# %%
#dictionary comprehension

students = ['Arun','Ajay','bob']
marks = [80,95,90]

student_marks= {}

for student, mark in zip(students,marks):
    student_marks[student] = mark

# %%
student_marks
# Out:
# {'Arun': 80, 'Ajay': 95, 'bob': 90}

# %%
for i in zip(students,marks):
    print(i)
# Out:
# ('Arun', 80)
# ('Ajay', 95)
# ('bob', 90)

# %%
{student:marks for student, marks in zip(students,marks)}
# Out:
# {'Arun': 80, 'Ajay': 95, 'bob': 90}

# %%
user_id = [1,2,3]
user_name = ["a21","a22","a33"]
{u_id:u_name for u_id , u_name in zip(user_id,user_name)}
# Out:
# {1: 'a21', 2: 'a22', 3: 'a33'}

# %%
employee_records = {
    'E001' : {'name': 'raja', 'department': 'engineering','salary': '64000'},
    'E002' : {'name': 'bhanu', 'department': 'marketing', 'salary': '65000'},
    'E003' : {'name': 'rana', 'department': 'finance', 'salary': '90000'},
}

# %%
employee_records['E002']
# Out:
# {'name': 'bhanu', 'department': 'marketing', 'salary': '65000'}

# %%
employee_records
# Out:
# {'E001': {'name': 'raja', 'department': 'engineering', 'salary': '64000'},
#  'E002': {'name': 'bhanu', 'department': 'marketing', 'salary': '65000'},
#  'E003': {'name': 'rana', 'department': 'finance', 'salary': '90000'}}

# %%
restaurant_menu = {
    'Dish1' : {'name': 'Margherita pizza','price': '15.99$','Discription': 'pizza topped with tomato,mozzarella, and basil'},
    'Dish2' : {'name': 'Pasta carbonara', 'price': '14.90$', 'Discription': 'creamy pasta with bacon and parmesan'},
    'Dish3' : {'name': 'chiken salad','price': '21$','Discription': 'Grilled chiken'}
}

# %%
restaurant_menu
# Out:
# {'Dish1': {'name': 'Margherita pizza',
#   'price': '15.99$',
#   'Discription': 'pizza topped with tomato,mozzarella, and basil'},
#  'Dish2': {'name': 'Pasta carbonara',
#   'price': '14.90$',
#   'Discription': 'creamy pasta with bacon and parmesan'},
#  'Dish3': {'name': 'chiken salad',
#   'price': '21$',
#   'Discription': 'Grilled chiken'}}

# %%
#Dictionary view objects
restaurant_menu.keys()
# Out:
# dict_keys(['Dish1', 'Dish2', 'Dish3'])

# %%
restaurant_menu.values()

# %%
restaurant_menu.items()
# Out:
# dict_items([('Dish1', {'name': 'Margherita pizza', 'price': '15.99$', 'Discription': 'pizza topped with tomato,mozzarella, and basil'}), ('Dish2', {'name': 'Pasta carbonara', 'price': '14.90$', 'Discription': 'creamy pasta with bacon and parmesan'}), ('Dish3', {'name': 'chiken salad', 'price': '21$', 'Discription': 'Grilled chiken'})])
