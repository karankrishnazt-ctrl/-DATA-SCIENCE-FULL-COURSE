# %%
list = [1,2,3,"abhi","ddlj",3+78j]
list[0]
# Out:
# 1

# %%
list.append("abhinay") # append -> add item at end
print(list)
# Out:
# [1, 2, 3, 'abhi', 'ddlj', (3+78j), 'abhinay']

# %%
list.remove("abhi")
print(list)
# Out:
# [1, 2, 3, 'ddlj', (3+78j), 'abhinay']

# %%
type(list[4])
# Out:
# complex

# %%
lis = [[1,2,3],[4,5,5],[6,7,8]]
lis[2][1]
# Out:
# 7

# %%
#tuple >> immutable

# %%
point = (1,2,"abhigyan", "susama")
print(point)
# Out:
# (1, 2, 'abhigyan', 'susama')

# %%
point[3]
# Out:
# 'susama'

# %%
box1 = ("a","b")
box2 = ("c","d")

choclate_bag = (box1,box2)
choclate_bag
# Out:
# (('a', 'b'), ('c', 'd'))

# %%
for box in choclate_bag:
    for abcd in box:
        print(abcd)
# Out:
# a
# b
# c
# d

# %%
#sets >> are unordered collection of unique element

# %%
s = {"a","b"}
s
# Out:
# {'a', 'b'}

# %%
s = {"a","a","a","b",1234}
s
# Out:
# {1234, 'a', 'b'}

# %%
s[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 s[1]
#
# TypeError: 'set' object is not subscriptable

# %%
#dictionary >> key values pair
my_dict = {}

# %%
type(my_dict)
# Out:
# set

# %%
my_dict = {"key_course" : "ds","duration" : 2}
my_dict
# Out:
# {'key_course': 'ds', 'duration': 2}

# %%
phone_no = {"dad":234,"mom":9012,"dad":23412}
phone_no["dad"]
# Out:
# 23412

# %%
phone_no.keys()
# Out:
# dict_keys(['dad', 'mom'])

# %%
phone_no.values()
# Out:
# dict_values([23412, 9012])

# %%
phone_no["dad"] = "change no."
phone_no
# Out:
# {'dad': 'change no.', 'mom': 9012}

# %%
from array import array #array >> array is similar to list (homogenos data)
array('i',[1,1,2,3,4])
a = array('i',[1,1,2,3,4])

# %%
a[3]
# Out:
# 3

# %%
array('i',["abhishek"])
a = array('i',[1,2,3,"abhishek"])
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 array('i',["abhishek"])
#       2 a = array('i',["abhishek"])
#       3 print(a)
#
# TypeError: 'str' object cannot be interpreted as an integer
