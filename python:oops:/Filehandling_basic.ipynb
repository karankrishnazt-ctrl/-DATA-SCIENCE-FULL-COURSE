# %%
# r >> read mode
# w >> write mode
# a >> appending mode
# r+ >> both read and write

file = open("file.txt","w")

# %%
file.write("Hello, this is my first line") # number below is no. of bytes
# Out:
# 28

# %%
file.close()

# %%
# file attributes

file
# Out:
# <_io.TextIOWrapper name='file.txt' mode='w' encoding='UTF-8'>

# %%
file.closed
# Out:
# True

# %%
file.name
# Out:
# 'file.txt'

# %%
file.mode
# Out:
# 'w'

# %%
file.write("This is my second line")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 file.write("This is my second line")
#
# ValueError: I/O operation on closed file.

# %%
file = open("file.txt",'w')

# %%
file.write("This is my second line")
# Out:
# 22

# %%
file.close()

# %%
file = open("file.txt",'w')
file.write("This is my second line\n")
file.write("This is my third line\n")
file.write("This is my fourth line\n")
file.close()

# %%
file = open("file.txt",'a')
file.write("this is fifth line")
file.close()

# %%
file = open("file.txt","r")

# %%
file.write("pp is guy") # this is not execute becoz it is in read mode
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 file.write("pp is guy")
#
# AttributeError: 'tuple' object has no attribute 'write'

# %%
for i in file:
    print(i)
# Out:
# This is my second line
#
# This is my third line
#
# This is my fourth line
#
# this is fifth line

# %%
print(file.read()) # here the cursor or pointer is at last position

# %%
file.tell() # it tell the current position of cursor
# Out:
# 86

# %%
file.seek(0) # cursor move to intial place
# Out:
# 0

# %%
file.read()
# Out:
# 'This is my second line\nThis is my third line\nThis is my fourth line\nthis is fifth line'

# %%
f = open("file.txt",'r')
print(f.readline())
f.close()
# Out:
# This is my second line

# %%
file = open("file.txt",'r')
file.seek(0)
print(file.read())
file.close()
# Out:
# This is my second line
# This is my third line
# This is my fourth line
# this is fifth line

# %%
f = open("file.txt",'r')
print(f.readlines())
f.close()
# Out:
# ['This is my second line\n', 'This is my third line\n', 'This is my fourth line\n', 'this is fifth line']

# %%
import os

# %%
pwd
# Out:
# '/Users/karankrishna/Documents/kk_python/python '

# %%
os.getcwd()
# Out:
# '/Users/karankrishna/Documents/kk_python/python '

# %%
ls

# %%
os.path.getsize("file.txt")
# Out:
# 86

# %%
os.mkdir("test")

# %%
os.mkdir("test/test1")

# %%
os.makedirs("1/2/3/4")

# %%
os.listdir()

# %%
os.mkdir("feat")

# %%
os.rmdir("feat")

# %%
os.rmdir("test")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 os.rmdir("test")
#
# OSError: [Errno 66] Directory not empty: 'test'

# %%
import shutil
shutil.rmtree("1")

# %%
os.getcwd()
# Out:
# '/Users/karankrishna/Documents/kk_python/python '

# %%
os.makedirs("/Users/karankrishna/Documents/kk_python/python/test/test1/", exist_ok=True)
f = open("/Users/karankrishna/Documents/kk_python/python/test/test1/file_test.txt","w")

# %%
shutil.copy("/Users/karankrishna/Documents/kk_python/python/test/test1/file_test.txt","/Users/karankrishna/Documents/kk_python/python")
# Out:
# '/Users/karankrishna/Documents/kk_python/python/file_test.txt'

# %%
shutil.move("/Users/karankrishna/Documents/kk_python/python/test/test1/file_test.txt","/Users/karankrishna/Documents/kk_python/python")

# %%
os.mkdir("test_move")

# %%
os.remove("file_test.txt")

# %%
with open ("file.txt","r") as f:
    line = f.readline()
    print(line)
# Out:
# This is my second line
