# %%
temp = 30
if temp > 25:
    print("Room temp")

# %%
is_ds_course = True
if is_ds_course:
    print("I am studying this course")
# Out:
# I am studying this course

# %%
is_ds_course = False
if is_ds_course:
    print("I am studying this course")
else:
    print(" i am playing cricket")
# Out:
#  i am playing cricket

# %%
a = int(input(" enter your number "))
if a>=100:
    print("a is greater then 100")
elif 0<a<100:
    print("a is between 0 to 100")
else:
    print("negative number")
# Out:
# a is between 0 to 100

# %%
is_vip = False
age = 30

if is_vip:
    if age >= 18:
        if age < 65:
            print("welcome vip costumer")
        else:
            print("you are vip and also qulified for senior citizen")
    else:
        print("vip constomer only valid for senior citizen")            
else:
    print("sorry your are not vip")
# Out:
# vip constomer only valid for senior citizen

# %%
name = input("pls enter your name")
email = input("pls enter your email")
password = input("pls enter password")

if name == "":
    print("name can not be empty")
else:
    if "@" not in email:
        print("invalid email")
    else:
        if len(password) < 0:
            print("invalid password")
        else:
            print("registration successful")
# Out:
# registration successful
