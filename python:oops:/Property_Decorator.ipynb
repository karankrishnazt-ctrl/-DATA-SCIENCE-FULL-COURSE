# %%
class Student:
    def __init__(self,name,price):
        self.__name = name
        self.__price = price

# %%
stud = Student("priyanka",4000)

# %%
stud.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 stud.name
#
# AttributeError: 'Student' object has no attribute 'name'

# %%
class Student:
    def __init__(self,name,price):
        self.__name = name
        self.__price = price

    @property # it will make access_price as attribute of the class
    def access_price(self):
        return self.__price

# %%
stud = Student("rr",3000)

# %%
stud._Student__name
# Out:
# 'rr'

# %%
stud.access_price
# Out:
# 3000

# %%
class Student:
    def __init__(self,name,price):
        self.__name = name
        self.__price = price

    @property
    def access_price(self):
        return self.__price
    @access_price.setter
    def price_set(self,price_new):
        self.__price = price_new

# %%
stud = Student("KK",3400)

# %%
stud.access_price
# Out:
# 3400

# %%
stud.price_set = 1500

# %%
stud.access_price
# Out:
# 1500

# %%
class Student:
    def __init__(self,name,price):
        self.__name = name
        self.__price = price

    @property
    def access_price(self):
        return self.__price
    @access_price.setter
    def price_set(self,price_new):
        self.__price = price_new

    @access_price.deleter
    def del_price(self):
        del self.__price

# %%
stud = Student("kk",3000)

# %%
stud.access_price
# Out:
# 3000

# %%
stud.price_set = 2300

# %%
stud.access_price
# Out:
# 2300

# %%
del stud.del_price

# %%
stud.access_price
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 stud.access_price
#
# Cell In[13], line 8, in Student.access_price(self)
#       6     @property
#       7     def access_price(self):
# ----> 8         return self.__price
#
# AttributeError: 'Student' object has no attribute '_Student__price'

# %%
class Circle:
    def __init__(self,radius):
        self.__radius = radius
    @property
    def radius(self):
        return self.__radius

# %%
c = Circle(5)

# %%
c.radius
# Out:
# 5

# %%
class Circle:
    def __init__(self,radius):
        self.__radius = radius
    @property
    def radius(self):
        return self.__radius
    @radius.setter
    def radius(self, value):
        if value <= 0:
            raise ValueError("Radius is not pos")
        self.__radius = value
    def area(self):
        return 3.14 * self.__radius **2

# %%
c = Circle(5)

# %%
c.radius
# Out:
# 5

# %%
c.radius = 20

# %%
c.radius
# Out:
# 20

# %%
c.radius = -2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 c.radius = -2
#
# Cell In[27], line 10, in Circle.radius(self, value)
#       7     @radius.setter
#       8     def radius(self, value):
#       9         if value <= 0:
# ---> 10             raise ValueError("Radius is not pos")
#      11         self.__radius = value
#
# ValueError: Radius is not pos

# %%
class Circle:
    def __init__(self,radius):
        self.__radius = radius
    @property
    def radius(self):
        return self.__radius
    @radius.setter
    def radius(self, value):
        if value <= 0:
            raise ValueError("Radius is not pos")
        self.__radius = value
    @radius.deleter
    def radius(self):
        del self.__radius
    def area(self):
        return 3.14 * self.__radius **2

# %%
c = Circle(7)

# %%
c.radius
# Out:
# 7

# %%
del c.radius

# %%
c.radius
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 c.radius
#
# Cell In[35], line 6, in Circle.radius(self)
#       4     @property
#       5     def radius(self):
# ----> 6         return self.__radius
#
# AttributeError: 'Circle' object has no attribute '_Circle__radius'
