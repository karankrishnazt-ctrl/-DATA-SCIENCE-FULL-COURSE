# %%
#what is operators>> special keywords to perform operations 
#why? to manipualte data


#arithmatic operator
a = 5
b = 2
a+b
# Out:
# 7

# %%
20-3
# Out:
# 17

# %%
add = 5+2
print(add)
# Out:
# 7

# %%
2**3 # 2*2*2
# Out:
# 8

# %%
2*4
# Out:
# 8

# %%
#compation operator >> campare two values >> return a boolean value

2 == 2
# Out:
# True

# %%
#logical operator
True and True
# Out:
# True

# %%
"am" in "i am student"
# Out:
# True

# %%
a = ["data" , "science" , "math"]
"dat" not in a
# Out:
# True

# %%
12 ^ 5 # ^ -> XOR
# Out:
# 9

# %%
bin(12) # bin -> binary
# Out:
# '0b1100'

# %%
bin(5)
# Out:
# '0b101'

# %%
#left shift <<
120 << 3
# when using left shift , it only add 0es at rightside like 3 is given then 120 bin add 0es at end and convert into decial. 
# bin(120) -> 1111000
# bin(960) -> 1111000000
# Out:
# 960

# %%
bin(120)
# Out:
# '0b1111000'

# %%
bin(960)
# Out:
# '0b1111000000'

# %%
#right shift operator >> it removes the number of elements in the binary
11 >> 3
# Out:
# 1

# %%
bin(11)
# Out:
# '0b1011'

# %%
bin(3)
# Out:
# '0b11'

# %%
a=4
a=b
a is b
# Out:
# True

# %%
a = 3 + b
b = 7
a is not b
# Out:
# True
