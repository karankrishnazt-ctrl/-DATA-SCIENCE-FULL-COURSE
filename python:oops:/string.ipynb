# %%
ord('a') #ascii value
# Out:
# 97

# %%
chr(97)
# Out:
# 'a'

# %%
#special 
'\u0973'
# Out:
# 'ॳ'

# %%
chr(975)
# Out:
# 'Ϗ'

# %%
#string are immutable

# %%
string1 = "i love songs"
string1[0]
# Out:
# 'i'

# %%
string1[0:6]
# Out:
# 'i love'

# %%
string1[-5]
# Out:
# 's'

# %%
string1[::-1]
# Out:
# 'sgnos evol i'

# %%
len(string1)
# Out:
# 12

# %%
string1.replace('songs','movie')
# Out:
# 'i love movie'

# %%
sentence = "I am karan krishna"
search_word = "am"

if search_word in sentence:
    print("search word present")
else:
    print("not")
# Out:
# search word present

# %%
email = "kak1234@gmail.com"

if "@" in email:
    print("valid email")
else:
    print("invalid")
# Out:
# valid email

# %%
pdff = "kk_231.pdf"

if "pdf" in pdff:
    print("its a pdf file")
else:
    print("invalid")
# Out:
# its a pdf file

# %%
#string order
list = ["ak","kk","ss","md","rk"]
sorted(list)

# %%
#commo string operation


input_string ="         hiiiii lol          "
input_string.strip()
# Out:
# 'hiiiii lol'

# %%
#string split
data = "dursan,farrera,jamali"
data
# Out:
# 'dursan,farrera,jamali'

# %%
data_info = data.split(',')
data_info
# Out:
# ['dursan', 'farrera', 'jamali']

# %%
#Escape sequence >> special combination of characters used within a string 

adress = "123,sanmukha villa,\nmarathali,\nbangalore"
print(adress) #\n >> to insert a new line character
# Out:
# 123,sanmukha villa,
# marathali,
# bangalore

# %%
#\t >> escape character
table = "Name\tage\tGrade\nAlice\t20\tA\nRam\t30\tA+"
print(table)
# Out:
# Name	age	Grade
# Alice	20	A
# Ram	30	A+

# %%
#\' single quote escape 
str1 = 'I can\'t belive its a friday'
str1
# Out:
# "I can't belive its a friday"

# %%
#carriage reture \r >> move the cursor to the beginning of line.
print("hello, I am \rkk. I am going to delhi.")
# Out:
# kk. I am going to delhi.

# %%
#string formatting >> creating string with placeholder for variables
username = "vivek"
greeting = f'hello {username}, how are you?'
print(greeting)
# Out:
# hello vivek, how are you?

# %%
#.format
template = "hello, {} welcome to {} "
message = template.format("zishan","london") 
print(message)
# Out:
# hello, zishan welcome to london

# %%
#f string 
course = "b.tech"
duration = 4

f"my {course} degree complete in {duration} years"
# Out:
# 'my b.tech degree complete in 4 years'

# %%
str1 = "fezal khan" 
str1.startswith("f")
# Out:
# True

# %%
str1 = "fezal khan" 
str1.endswith("n")
# Out:
# True
