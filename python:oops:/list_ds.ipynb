# %%
list1 = ["apple","banana","mango"]
list1

# %%
list1[1] = "orange"
list1

# %%
list1.append("chiku")
list1

# %%
list1.insert(1,"peach")
list1

# %%
#extend >> used to append elements from another iterable
my_list = ["apple","orange","mango"]
brother_list = ["brinjal","tomato"]

my_list.extend(brother_list)
my_list
# Out:
# ['apple', 'orange', 'mango', 'brinjal', 'tomato']

# %%
my_list = ["apple","orange","mango"]
brother_list = ["brinjal","tomato"]

# %%
my_list+brother_list
# Out:
# ['apple', 'orange', 'mango', 'brinjal', 'tomato']

# %%
"!" * 5
# Out:
# '!!!!!'

# %%
[1,2]*5
# Out:
# [1, 2, 1, 2, 1, 2, 1, 2, 1, 2]

# %%
list(range(1,5)) * 2
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
msg = "hello buddy \n"
print(msg*2)
# Out:
# hello buddy
# hello buddy

# %%
grocery_list = ["milk","banana"]

# %%
a = grocery_list
a
# Out:
# ['milk', 'banana']

# %%
a[0] = "mango"
a
# Out:
# ['mango', 'banana']

# %%
#deep copy and shallow copy
b = grocery_list.copy()

# %%
grocery_list[0] = "grapes"
grocery_list # shallow copy >> it will not change
# Out:
# ['grapes', 'banana']

# %%
b # deep copy >> does not change
# Out:
# ['mango', 'banana']

# %%
# sorting list

book_list = ["ds","da","python","java","c"]
sorted(book_list)
# Out:
# ['c', 'da', 'ds', 'java', 'python']

# %%
book_list.index("da")
# Out:
# 1

# %%
book_list = ["ds","ds","da","python","java","c"]
book_list.count("ds")
# Out:
# 2

# %%
book_list.remove("ds")
book_list
# Out:
# ['da', 'python', 'java', 'c']

# %%
book_list.sort()
book_list
# Out:
# ['c', 'da', 'java', 'python']

# %%
del book_list

# %%
book_list = ['c', 'da', 'java', 'python']
book_list.clear()

# %%
book_list
# Out:
# []

# %%
book_list = ['c', 'da', 'java', 'python']
book_list.pop() # pop >> remove last element
# Out:
# 'python'

# %%
book_list.pop(2)
# Out:
# 'java'

# %%
# list comprehension
prices = [10,20,30,40,50]
double_price = []

for price in prices:
    double_price.append(price*2)

# %%
double_price
# Out:
# [20, 40, 60, 80, 100]

# %%
double_price =[price * 2 for price in prices]
double_price
# Out:
# [20, 40, 60, 80, 100]

# %%
numbers = [1,2,3,4,5]
[num ** 2 for num in numbers]
# Out:
# [1, 4, 9, 16, 25]

# %%
file_name = ["doc1.py","doc2.ppt","doc3.pdf","doc4.jpg"]
[file.split(".")[-1] for file in file_name]
# Out:
# ['py', 'ppt', 'pdf', 'jpg']

# %%
str1 = "doc1.py"
str1.split(".")[-1]
# Out:
# 'py'

# %%
# conditional list statement 

email_address = ["kk@gmail.com","pk@gmail.com","sk@yahoo.com","ss@yahoo.com"]
[email for  email in email_address if email.endswith("@yahoo.com")]
# Out:
# ['sk@yahoo.com', 'ss@yahoo.com']

# %%
#nested list comprehension

pair = []
for x in [1,2,3]:
    for y in [4,5,6]:
        pair.append((x,y))

# %%
pair
# Out:
# [(1, 4), (1, 5), (1, 6), (2, 4), (2, 5), (2, 6), (3, 4), (3, 5), (3, 6)]

# %%
[[x,y] for x in [1,2,3] for y in [4,5,6]]
# Out:
# [[1, 4], [1, 5], [1, 6], [2, 4], [2, 5], [2, 6], [3, 4], [3, 5], [3, 6]]

# %%
# list as stack and queue

#stack >> fast in last out

stack_of_plate = []
stack_of_plate.append("plate1")
stack_of_plate.append("plate2")
stack_of_plate.append("plate3")
stack_of_plate.append("plate4")
stack_of_plate
# Out:
# ['plate1', 'plate2', 'plate3', 'plate4']

# %%
stack_of_plate.pop()
# Out:
# 'plate4'

# %%
stack_of_plate
# Out:
# ['plate1', 'plate2', 'plate3']

# %%
# Queue >> FIFO >> First in first out 

from collections import deque

checkout = deque()
checkout.append("cus1")
checkout.append("cus2")
checkout.append("cus3")
checkout.append("cus4")
checkout
# Out:
# deque(['cus1', 'cus2', 'cus3', 'cus4'])

# %%
while checkout:
    customer = checkout.popleft()
    print("serving",customer)
# Out:
# serving cus1
# serving cus2
# serving cus3
# serving cus4

# %%
checkout.popleft()
# Out:
# 'cus1'

# %%
from queue import Queue

# %%
print_queue = Queue()

print_queue.put("print job1")
print_queue.put("print job2")
print_queue.put("print job3")

while not  print_queue.empty():
    print_job = print_queue.get()
    print("printing", print_job)
# Out:
# printing print job1
# printing print job2
# printing print job3
