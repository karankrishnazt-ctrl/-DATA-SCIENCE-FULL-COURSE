# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://karankrishnazt_db_user:ODHCtRgoPwZ1bFUh@cluster0.im9k8t2.mongodb.net/?appName=Cluster0")

# %%
client
# Out:
# MongoClient(host=['ac-ynmjevt-shard-00-01.im9k8t2.mongodb.net:27017', 'ac-ynmjevt-shard-00-02.im9k8t2.mongodb.net:27017', 'ac-ynmjevt-shard-00-00.im9k8t2.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-pr1x9t-shard-0', ssl=True)

# %%
db = client["Tokyo"]

# %%
coll_create = db["my_record"]

# %%
data = {"name" : "kk",
        "class" : "data science",
        "timing" : "flexi"
}

# %%
coll_create.insert_one(data)

# %%
data2 = {"list_course" : ["data sience","web dev", "java with DSA"],
        "mentor" : ['viswa','ravi','arun']}

# %%
coll_create.insert_one(data2)

# %%
data3 = [
  { "name": "Amy", "address": "Apple st 652" },
  { "name": "Hannah", "address": "Mountain 21" },
  { "name": "Michael", "address": "Valley 345" },
  { "name": "Sandy", "address": "Ocean blvd 2" },
  { "name": "Betty", "address": "Green Grass 1" },
  { "name": "Richard", "address": "Sky st 331" },
  { "name": "Susan", "address": "One way 98" },
  { "name": "Vicky", "address": "Yellow Garden 2" },
  { "name": "Ben", "address": "Park Lane 38" },
  { "name": "William", "address": "Central st 954" },
  { "name": "Chuck", "address": "Main Road 989" },
  { "name": "Viola", "address": "Sideway 1633" }
]

# %%
coll_create.insert_many(data3)

# %%
data4 = {
    "name" : "notebook",
    "qty" : 50,
    "rating" : [{"score" : 8},{"score" : 9}],
    "size" : {"height" : 11, "width" : 8.5, "unit" : "in"},
    "status" : 'A',
    "tags" : ["collage-ruled", "perforated"]
}

# %%
coll_create.insert_one(data4)

# %%
for i in coll_create.find():
    print(i)
# Out:
# {'_id': ObjectId('6a72f3d2d38f702415ad3366'), 'name': 'kk', 'class': 'data science', 'timing': 'flexi'}
# {'_id': ObjectId('6a72f53ed38f702415ad3368'), 'list_course': ['data sience', 'web dev', 'java with DSA'], 'mentor': ['viswa', 'ravi', 'arun']}
# {'_id': ObjectId('6a72f607d38f702415ad3369'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('6a72f607d38f702415ad336a'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('6a72f607d38f702415ad336b'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('6a72f607d38f702415ad336c'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('6a72f607d38f702415ad336d'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('6a72f607d38f702415ad336e'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('6a72f607d38f702415ad336f'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('6a72f607d38f702415ad3370'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# ...

# %%
random_data = [
    {'_id': '3', 'companyName': 'Infosys', 'Faculty': 'XYZ'},
    {'_id': '4', 'companyName': 'Infosys', 'Faculty': 'ABC'},
    {'_id': '5', 'companyName': 'Infosys', 'Faculty': 'PQR'},
]

# %%
coll_create.insert_many(random_data)

# %%
for i in coll_create.find({'companyName' : 'Infosys'}):
    print(i)
# Out:
# {'_id': '3', 'companyName': 'Infosys', 'Faculty': 'XYZ'}
# {'_id': '4', 'companyName': 'Infosys', 'Faculty': 'ABC'}
# {'_id': '5', 'companyName': 'Infosys', 'Faculty': 'PQR'}

# %%
for i in coll_create.find({'_id':{'$gte': '4' }}):
    print(i)
# Out:
# {'_id': '4', 'companyName': 'Infosys', 'Faculty': 'ABC'}
# {'_id': '5', 'companyName': 'Infosys', 'Faculty': 'PQR'}

# %%
coll_create.update_many({'companyName' : 'Infosys'},{'$set' :{'companyName' : 'ITC'}})

# %%
for i in coll_create.find():
    print(i)
# Out:
# {'_id': ObjectId('6a72f3d2d38f702415ad3366'), 'name': 'kk', 'class': 'data science', 'timing': 'flexi'}
# {'_id': ObjectId('6a72f53ed38f702415ad3368'), 'list_course': ['data sience', 'web dev', 'java with DSA'], 'mentor': ['viswa', 'ravi', 'arun']}
# {'_id': ObjectId('6a72f607d38f702415ad3369'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('6a72f607d38f702415ad336a'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('6a72f607d38f702415ad336b'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('6a72f607d38f702415ad336c'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('6a72f607d38f702415ad336d'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('6a72f607d38f702415ad336e'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('6a72f607d38f702415ad336f'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('6a72f607d38f702415ad3370'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# ...

# %%
coll_create.drop()

# %%
for i in coll_create.find():
    print(i)
